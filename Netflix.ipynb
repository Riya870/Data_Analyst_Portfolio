# %% [markdown]
# # Netflix Dataset Analysis

# %% [markdown]
# In this project we are going to analyze the netflix dataset about TV shows and Movies. This dataset is available on Kaggle website

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix_datasets.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
#display  top 10 rows
df.head(10)
# Out:
#    Unnamed: 0 show_id     type                                title  \
# 0           0      s1    Movie                 Dick Johnson Is Dead
# 1           1      s2  TV Show                        Blood & Water
# 2           2      s3  TV Show                            Ganglands
# 3           3      s4  TV Show                Jailbirds New Orleans
# 4           4      s5  TV Show                         Kota Factory
# 5           5      s6  TV Show                        Midnight Mass
# 6           6      s7    Movie     My Little Pony: A New Generation
# 7           8      s9  TV Show        The Great British Baking Show
# 8           9     s10    Movie                         The Starling
# 9          10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# ...

# %%
#number of rows and  columns
df.shape
# Out:
# (8282, 13)

# %%
print("number of Rows",df.shape[0])
# Out:
# number of Rows 8282

# %%
print("number of Columns",df.shape[1])
# Out:
# number of Columns 13

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# show_id            0
# type               0
# title              0
# director        2582
# cast             807
# country          808
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'],
#       dtype='object')

# %% [markdown]
# # Check any Duplicate Records in the dataset ? If yes , then remove the duplicate records

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8277    False
# 8278    False
# 8279    False
# 8280    False
# 8281    False
# Length: 8282, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# There is no duplicate data in the dataset

# %% [markdown]
# # To check null value is present in any column?Show with Heat-map

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # For 'You Carry Me' , What is Show_id & who is the Director of this Show?

# %%
df[df['title'].isin(['You Carry Me'])]
# Out:
#       Unnamed: 0 show_id   type         title    director  \
# 8264        8788   s8789  Movie  You Carry Me  Ivona Juka
#
#                                                    cast  \
# 8264  Lana Baric, Vojislav Brajovic, Natasa Janjic, ...
#
#                                     country    date_added  release_year  \
# 8264  Croatia, Slovenia, Serbia, Montenegro  July 1, 2016          2015
#
#      rating duration                     listed_in  \
# 8264  TV-MA  157 min  Dramas, International Movies
#
#                                             description
# 8264  A soap opera producer, director and makeup art...

# %% [markdown]
# # In Which year the highest number of the TV Shows & Movies were Released?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.head(2)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.release_year.value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# 2001      45
# 2000      37
# Name: count, dtype: int64

# %% [markdown]
# Most movies where released in 2018

# %%
df.release_year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# # How Many Movies and Tv Shows are in the dataset?

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5655
# TV Show    2627
# Name: count, dtype: int64

# %%
sns.countplot(x='type',data=df)
plt.title("Total number of  Movie & Tv Show")
plt.show()

# %% [markdown]
# # Show all the Tv Shows that were released  in year 2000

# %%
df.head(2)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df[(df.type =='TV Show') & (df.release_year==2000)]
# Out:
#       Unnamed: 0 show_id     type                            title director  \
# 2056        2173   s2174  TV Show                           Moesha      NaN
# 4917        5098   s5099  TV Show           Pokémon: Indigo League      NaN
# 5060        5245   s5246  TV Show               Star Trek: Voyager      NaN
# 7365        7766   s7767  TV Show  Power Rangers Lightspeed Rescue      NaN
#
#                                                    cast  \
# 2056  Brandy Norwood, William Allen Young, Sheryl Le...
# 4917  Rica Matsumoto, Ikue Otani, Mayumi Iizuka, Meg...
# 5060  Kate Mulgrew, Robert Beltran, Roxann Dawson, J...
# 7365  Michael Chaturantabut, Sean CW Johnson, Alison...
#
#                            country       date_added  release_year rating  \
# 2056                 United States   August 1, 2020          2000  TV-PG
# 4917                         Japan  January 1, 2018          2000  TV-Y7
# 5060                 United States  October 1, 2017          2000  TV-PG
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
sns.histplot(x='type',y='release_year',bins=5, kde=True, color='lightgreen', edgecolor='red',data=df)
plt.show()

# %% [markdown]
# # show only the title of all TV Shows that were released in India only

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df[(df.type == 'TV Show') & (df.country == 'India')]['title']
# Out:
# 4                             Kota Factory
# 35                            Chhota Bheem
# 42                           Dharmakshetra
# 58           Raja Rasoi Aur Anya Kahaniyan
# 60          Stories by Rabindranath Tagore
#                        ...
# 7716                             Thackeray
# 7773                           The Calling
# 7847    The Golden Years with Javed Akhtar
# 7874                The House That Made Me
# 8251                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# # Show Top 10 Directors , who gave the highest number of TV Show & Movies to Netflix?

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Don Michael Paul          10
# Kunle Afolayan             8
# Shannon Hartman            8
# Name: count, dtype: int64

# %% [markdown]
# # How many movies/shows ,Adam Sandler was cast?

# %%
df.head(2)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# show_id            0
# type               0
# title              0
# director        2582
# cast             807
# country          808
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1
# Out:
#       Unnamed: 0 show_id     type                          title  \
# 7              8      s9  TV Show  The Great British Baking Show
# 8              9     s10    Movie                   The Starling
# 11            12     s13    Movie                   Je Suis Karl
# 23            27     s28    Movie                      Grown Ups
# 24            28     s29    Movie                     Dark Skies
# ...          ...     ...      ...                            ...
# 8276        8801   s8802    Movie                        Zinzana
# 8277        8802   s8803    Movie                         Zodiac
# 8279        8804   s8805    Movie                     Zombieland
# 8280        8805   s8806    Movie                           Zoom
# 8281        8806   s8807    Movie                         Zubaan
#
#                  director                                               cast  \
# 7         Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
df1[df1['cast'].str.contains('Adam Sandler')]
# Out:
#       Unnamed: 0 show_id   type                                      title  \
# 23            27     s28  Movie                                  Grown Ups
# 1766        1879   s1880  Movie                            Hubie Halloween
# 2339        2471   s2472  Movie                                 Uncut Gems
# 3597        3753   s3754  Movie                             Murder Mystery
# 4314        4482   s4483  Movie                    ADAM SANDLER 100% FRESH
# 4736        4912   s4913  Movie                                The Week Of
# 5042        5227   s5228  Movie  The Meyerowitz Stories (New and Selected)
# 5326        5533   s5534  Movie                               Sandy Wexler
# 5632        5846   s5847  Movie                                The Do-Over
# 5665        5879   s5880  Movie                           The Ridiculous 6
# 5789        6018   s6019  Movie                             50 First Dates
# ...

# %% [markdown]
# #  What are the different Ratings defined by Netflix ?

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.rating.value_counts()
# Out:
# rating
# TV-MA       3143
# TV-14       2027
# TV-PG        809
# R            688
# PG-13        421
# TV-Y7        325
# TV-Y         305
# PG           240
# TV-G         208
# NR            73
# G             25
# TV-Y7-FV       6
# NC-17          3
# UR             2
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# # How many Movies got the 'TV-MA' rating, in Canada ?

# %%
df[(df.type =='Movie')&(df.rating == 'TV-MA')&(df.country == 'Canada')].shape
# Out:
# (41, 13)

# %% [markdown]
# # What is the maximum duration of a Movie/Show on Netflix ?

# %%
df.head(2)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.duration.dtypes
# Out:
# dtype('O')

# %%
df[['length','unit']]= df.duration.str.split(' ',expand =True)

# %%
df.head(2)
# Out:
#    Unnamed: 0 show_id     type                 title         director  \
# 0           0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description length     unit
# 0  As her father nears the end of his life, filmm...     90      min
# 1  After crossing paths at a party, a Cape Town t...      2  Seasons

# %%
df[df.unit == 'min']['length'].max()
# Out:
# '99'

# %%
df[df.unit == 'Seasons']['length'].max()
# Out:
# '9'

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description', 'length', 'unit'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...
